# %%
from sklearn.datasets import load_breast_cancer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate
import matplotlib.pyplot as plt

cancer = load_breast_cancer()
X = cancer.data
y = cancer.target

k_range = range(1, 31)
train_scores = []
test_scores = []
for n_neighbor in k_range:
    knn = KNeighborsClassifier(n_neighbors=n_neighbor)
    cv_result = cross_validate(knn, X, y, cv=5, return_train_score=True)
    train_scores.append(cv_result['train_score'].mean())
    test_scores.append(cv_result['test_score'].mean())
plt.plot(k_range,train_scores,c='b', label='training')
plt.plot(k_range,test_scores,c='r', label='testing')
plt.xlabel('size of nearest neighbors')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# cross_validate return 的字典的keys
cv_result.keys()
# Out:
# dict_keys(['fit_time', 'score_time', 'test_score', 'train_score'])

# %%
# 另一種畫法
plt.plot(k_range,train_scores,c='b')
plt.plot(k_range,test_scores,c='r')
plt.xlabel('size of nearest neighbors')
plt.ylabel('Accuracy')
plt.legend(['training', 'testing'])
plt.show()
